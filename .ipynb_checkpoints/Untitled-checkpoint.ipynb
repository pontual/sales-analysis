# %%
pwd()
# Out:
# 'C:\\Users\\Heitor\\Desktop\\code\\sales-analysis'

# %%
from excelparser import parse_sales
import numpy as np
import pandas as pd

# %%
i = parse_sales("data/numsp.xls", "data/prodp.xls", "data/outp.csv")
# Out:
# WARNING *** file size (314986) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (773940) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# PON
# Wrote data/outp.csv

# %%
df = pd.read_csv("data/outp.csv")

# %%
df
# Out:
#             data   codigo  qtde
# 0     2019-08-02  140873P  2000
# 1     2019-08-06  140873P  1005
# 2     2019-08-07  140873P   300
# 3     2019-08-09  140873A     2
# 4     2019-08-12  140873A   101
# 5     2019-08-13  140873A    50
# 6     2019-08-14   143121  1000
# 7     2019-08-16  140873P   251
# 8     2019-08-16  140873S   251
# 9     2019-08-19  140873S   500
# 10    2019-08-19  140873P   200
# 11    2019-08-20  140873V   200
# 12    2019-08-21  140873V   205
# 13    2019-08-01  143294B    50
# 14    2019-08-02  143294G   205
# 15    2019-08-02  143294B   101
# 16    2019-08-05  143294G   100
# 17    2019-08-05  143294B   153
# 18    2019-08-06  143294G  2000
# 19    2019-08-15  143294B    30
# 20    2019-08-15  143294G     1
# 21    2019-08-19  143294B   600
# 22    2019-08-20  143294B    50
# 23    2019-08-20  143294A  1000
# 24    2019-08-20  143294G   400
# 25    2019-08-22  143294B    10
# 26    2019-08-23  143294G    30
# 27    2019-08-23  143294B    20
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set(style="whitegrid")

# %%
sns.lmplot(x="data", y="qtde", data=df, fit_reg=False)
