# %%
import pandas as pd

# %%
pwd()
# Out:
# 'C:\\Users\\Heitor\\Desktop\\code\\sales-analysis'

# %%
df = pd.read_csv("data/compiled.csv", index_col=0, parse_dates=True)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
dfkit = df.groupby(['codigo', 'data']).sum().loc['143035']

# %%
dfmonth = dfkit.groupby(pd.Grouper(freq="M")).sum()

# %%
pd.to_datetime("2015-07-08")
# Out:
# Timestamp('2015-07-08 00:00:00')

# %%
dfkit.dtypes
# Out:
# qtde    int64
# dtype: object

# %%
dfkit['year'] = dfkit.index.year
dfkit['month'] = dfkit.index.month

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
dfmonth['qtde'].plot()

# %%
dfmonth
# Out:
#              qtde
# data
# 2015-01-31   1159
# 2015-02-28    455
# 2015-03-31   1900
# 2015-04-30   1359
# 2015-05-31   4226
# 2015-06-30   1988
# 2015-07-31   7116
# 2015-08-31   6493
# 2015-09-30   4456
# 2015-10-31      2
# 2015-11-30   2174
# 2015-12-31   2736
# 2016-01-31    547
# 2016-02-29   1065
# 2016-03-31    827
# 2016-04-30   2055
# 2016-05-31    511
# 2016-06-30    433
# 2016-07-31    558
# 2016-08-31   1827
# 2016-09-30    656
# 2016-10-31    647
# 2016-11-30   4026
# 2016-12-31   1116
# 2017-01-31   1170
# 2017-02-28    403
# 2017-03-31    456
# 2017-04-30    898
# 2017-05-31   1083
# 2017-06-30    772
# 2017-07-31   6124
# 2017-08-31     22
# 2017-09-30      0
# 2017-10-31   7254
# 2017-11-30   7623
# 2017-12-31    119
# 2018-01-31    179
# 2018-02-28   1351
# 2018-03-31   2512
# 2018-04-30   2524
# 2018-05-31   5048
# 2018-06-30   2886
# 2018-07-31  18370
# 2018-08-31   3224
# 2018-09-30     10
# 2018-10-31   1364
# 2018-11-30   7506
# 2018-12-31   3150
# ...

# %%
dfkit
# Out:
#             qtde  year  month
# data
# 2015-01-05    61  2015      1
# 2015-01-07    50  2015      1
# 2015-01-08    51  2015      1
# 2015-01-09   440  2015      1
# 2015-01-13    50  2015      1
# 2015-01-15    51  2015      1
# 2015-01-19     5  2015      1
# 2015-01-20    60  2015      1
# 2015-01-22    20  2015      1
# 2015-01-27   100  2015      1
# 2015-01-28   270  2015      1
# 2015-01-30     1  2015      1
# 2015-02-02    50  2015      2
# 2015-02-03    60  2015      2
# 2015-02-04     1  2015      2
# 2015-02-10   130  2015      2
# 2015-02-13    30  2015      2
# 2015-02-19   120  2015      2
# 2015-02-24     1  2015      2
# 2015-02-25     2  2015      2
# 2015-02-26    60  2015      2
# 2015-02-27     1  2015      2
# 2015-03-03    35  2015      3
# 2015-03-09    60  2015      3
# 2015-03-10   200  2015      3
# 2015-03-12     1  2015      3
# 2015-03-13    10  2015      3
# 2015-03-18    41  2015      3
# 2015-03-20   100  2015      3
# 2015-03-24   141  2015      3
# ...
