# %%
from visualization import rolling_mean

# %%
from dataio import load_df

# %%
df = load_df()

# %%
rolling_mean(df, '143002A', 30)

# %%
rolling_mean(df, '143002A', 60)

# %%
rolling_mean(df, "143035", 60)

# %%
rolling_mean(df, "143035", 30)

# %%
rolling_mean(df, "141742", 60)

# %%
rolling_mean(df, "137350B", 60)

# %%
rolling_mean(df, "140078")

# %%
rolling_mean(df, "143187A")

# %%
rolling_mean(df, "143187S")

# %%
rolling_mean(df, "141306")
