# %%
pwd()
# Out:
# 'C:\\Users\\Heitor\\Desktop\\code\\sales-analysis'

# %%
from excelparser import parse_sales

# %%
parse_sales("data/numsp.xls", "data/prodp.xls")
# Out:
# WARNING *** file size (314986) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (773940) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# PON
# {'PON118236': (datetime.datetime(2019, 8, 20, 0, 0), '206 HANGARAGENS EIRELI'),
#  'PON117892': (datetime.datetime(2019, 8, 1, 0, 0),
#   'A 7 BRINDES COM. DE PROD. PERSONALIZ. LTDA. ME'),
#  'PON117893': (datetime.datetime(2019, 8, 1, 0, 0),
#   'A 7 BRINDES COM. DE PROD. PERSONALIZ. LTDA. ME'),
#  'PON117953': (datetime.datetime(2019, 8, 5, 0, 0),
#   'A 7 BRINDES COM. DE PROD. PERSONALIZ. LTDA. ME'),
#  'PON117977': (datetime.datetime(2019, 8, 6, 0, 0),
#   'A 7 BRINDES COM. DE PROD. PERSONALIZ. LTDA. ME'),
#  'PON118064': (datetime.datetime(2019, 8, 9, 0, 0),
#   'A 7 BRINDES COM. DE PROD. PERSONALIZ. LTDA. ME'),
#  'PON118072': (datetime.datetime(2019, 8, 9, 0, 0),
# ...
