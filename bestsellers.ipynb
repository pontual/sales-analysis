# %%
from visualization import plot_monthly

# %%
import pandas as pd

# %%
df = pd.read_csv("data/compiled.csv", index_col=0, parse_dates=True)

# %%
plot_monthly(df, "143035")

# %%
plot_monthly(df, "141742")

# %%
plot_monthly(df, "140873S")

# %%
plot_monthly(df, "143389A")

# %%
plot_monthly(df, "143002A")

# %%
from functools import partial
pplot = partial(plot_monthly, df)

# %%
pplot("140070")

# %%
pplot("141868")

# %%
pplot("143185")
