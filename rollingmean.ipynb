# %%
import pandas as pd

# %%
df = pd.read_csv("data/compiled.csv", index_col=0, parse_dates=True)

# %%
dfkit = df.groupby(['codigo', 'data']).sum().loc['143035']

# %%
dfkit
# Out:
#             qtde
# data
# 2015-01-05    61
# 2015-01-07    50
# 2015-01-08    51
# 2015-01-09   440
# 2015-01-13    50
# 2015-01-15    51
# 2015-01-19     5
# 2015-01-20    60
# 2015-01-22    20
# 2015-01-27   100
# 2015-01-28   270
# 2015-01-30     1
# 2015-02-02    50
# 2015-02-03    60
# 2015-02-04     1
# 2015-02-10   130
# 2015-02-13    30
# 2015-02-19   120
# 2015-02-24     1
# 2015-02-25     2
# 2015-02-26    60
# 2015-02-27     1
# 2015-03-03    35
# 2015-03-09    60
# 2015-03-10   200
# 2015-03-12     1
# 2015-03-13    10
# 2015-03-18    41
# 2015-03-20   100
# 2015-03-24   141
# ...          ...
# 2019-06-11    60
# 2019-06-13   150
# 2019-06-14   210
# 2019-06-19   100
# 2019-06-25    50
# 2019-06-26   220
# 2019-07-03    41
# 2019-07-05    30
# 2019-07-08   235
# 2019-07-10   520
# 2019-07-11    60
# 2019-07-12   180
# 2019-07-15   100
# 2019-07-16   395
# 2019-07-17  1687
# 2019-07-19   150
# 2019-07-24   120
# 2019-07-25    50
# 2019-07-26   201
# 2019-07-30    50
# ...

# %%
dfkit = dfkit.resample("B").sum()

# %%
dfkit
# Out:
#             qtde
# data
# 2015-01-05    61
# 2015-01-06     0
# 2015-01-07    50
# 2015-01-08    51
# 2015-01-09   440
# 2015-01-12     0
# 2015-01-13    50
# 2015-01-14     0
# 2015-01-15    51
# 2015-01-16     0
# 2015-01-19     5
# 2015-01-20    60
# 2015-01-21     0
# 2015-01-22    20
# 2015-01-23     0
# 2015-01-26     0
# 2015-01-27   100
# 2015-01-28   270
# 2015-01-29     0
# 2015-01-30     1
# 2015-02-02    50
# 2015-02-03    60
# 2015-02-04     1
# 2015-02-05     0
# 2015-02-06     0
# 2015-02-09     0
# 2015-02-10   130
# 2015-02-11     0
# 2015-02-12     0
# 2015-02-13    30
# ...          ...
# 2019-07-22     0
# 2019-07-23     0
# 2019-07-24   120
# 2019-07-25    50
# 2019-07-26   201
# 2019-07-29     0
# 2019-07-30    50
# 2019-07-31   145
# 2019-08-01   101
# 2019-08-02     0
# 2019-08-05     0
# 2019-08-06   173
# 2019-08-07    60
# 2019-08-08     3
# 2019-08-09     0
# 2019-08-12     3
# 2019-08-13     0
# 2019-08-14     0
# 2019-08-15     0
# 2019-08-16     0
# ...

# %%
dfr = dfkit['qtde'].rolling(30).mean()

# %%
import matplotlib.pyplot as plt

# %%
dfr.plot()

# %%
dfr
# Out:
# data
# 2015-01-05           NaN
# 2015-01-07           NaN
# 2015-01-08           NaN
# 2015-01-09           NaN
# 2015-01-13           NaN
# 2015-01-15           NaN
# 2015-01-19           NaN
# 2015-01-20           NaN
# 2015-01-22           NaN
# 2015-01-27           NaN
# 2015-01-28           NaN
# 2015-01-30           NaN
# 2015-02-02           NaN
# 2015-02-03           NaN
# 2015-02-04           NaN
# 2015-02-10           NaN
# 2015-02-13           NaN
# 2015-02-19           NaN
# 2015-02-24           NaN
# 2015-02-25           NaN
# 2015-02-26           NaN
# 2015-02-27           NaN
# 2015-03-03           NaN
# 2015-03-09           NaN
# 2015-03-10           NaN
# 2015-03-12           NaN
# 2015-03-13           NaN
# 2015-03-18           NaN
# 2015-03-20           NaN
# 2015-03-24     73.400000
#                  ...
# 2019-06-11    108.900000
# 2019-06-13    109.566667
# 2019-06-14    112.566667
# 2019-06-19    110.900000
# 2019-06-25    112.133333
# ...
